# %%
import pandas as pd
import matplotlib.pyplot as plt
from scripts.utils import load_csv, split_date, drop_columns, impute_rolling_median, add_seasonality, simplify_df, apply_moving_average_for_roc, split_data_frame, apply_functions
import tensorflow as tf
import time

# %% [markdown]
# ### Preprocessing

# %%
df = load_csv('../data/btc_timeseries.csv')
df = split_date(df, 'time')
df = simplify_df(df)
df = drop_columns(df, 10.0)
df = impute_rolling_median(df, 5)
df = add_seasonality(df)
df = apply_moving_average_for_roc(df, 'ema', 10, 20)
# Out:
# /Users/lucapetracca/Documents/GitHub/Transformers-Financial-Time-Series-Forecasting/models/scripts/utils.py:153: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[column].fillna(method='bfill', inplace=True)  # Backfill to address initial NaNs

# %%
train, val, test = split_data_frame(df, 0.7, 0.2)

# %%
X_train, y_train, X_val, y_val, X_test, y_test = apply_functions(train, test, val)
# Out:
# /Users/lucapetracca/Documents/GitHub/Transformers-Financial-Time-Series-Forecasting/models/scripts/utils.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_datetime(df[column], format="%d-%m-%Y")
# /Users/lucapetracca/Documents/GitHub/Transformers-Financial-Time-Series-Forecasting/models/scripts/utils.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_datetime(df[column], format="%d-%m-%Y")
# /Users/lucapetracca/Documents/GitHub/Transformers-Financial-Time-Series-Forecasting/models/scripts/utils.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_datetime(df[column], format="%d-%m-%Y")
# /Users/lucapetracca/Documents/GitHub/Transformers-Financial-Time-Series-Forecasting/models/scripts/utils.py:319: PerformanceWarning: Adding/subtracting object-dtype array to DatetimeArray not vectorized.
#   train[features_to_standardize] = (train[features_to_standardize] - train_mean) / train_std
# /Users/lucapetracca/Documents/GitHub/Transformers-Financial-Time-Series-Forecasting/models/scripts/utils.py:320: PerformanceWarning: Adding/subtracting object-dtype array to DatetimeArray not vectorized.
#   val[features_to_standardize] = (val[features_to_standardize] - train_mean) / train_std
# /Users/lucapetracca/Documents/GitHub/Transformers-Financial-Time-Series-Forecasting/models/scripts/utils.py:321: PerformanceWarning: Adding/subtracting object-dtype array to DatetimeArray not vectorized.
#   test[features_to_standardize] = (test[features_to_standardize] - train_mean) / train_std

# %%
from keras import layers

def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0, epsilon=1e-6, attention_axes=None, kernel_size=1):
    """
    Creates a single transformer block.
    """
    x = layers.LayerNormalization(epsilon=epsilon)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout,
        attention_axes=attention_axes
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=epsilon)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=kernel_size, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=kernel_size)(x)
    return x + res

# %%
def build_transfromer(head_size, num_heads, ff_dim, num_trans_blocks, mlp_units, dropout=0, mlp_dropout=0, attention_axes=None, epsilon=1e-6, kernel_size=1):
    """
    Creates final model by building many transformer blocks.
    """
    n_timesteps, n_features, n_outputs = X_train.shape[1], X_train.shape[2], 1
    inputs = tf.keras.Input(shape=(n_timesteps, n_features))
    x = inputs
    for _ in range(num_trans_blocks):
        x = transformer_encoder(x, head_size=head_size, num_heads=num_heads, ff_dim=ff_dim, dropout=dropout, attention_axes=attention_axes, kernel_size=kernel_size, epsilon=epsilon)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)

    outputs = layers.Dense(n_outputs)(x)
    return tf.keras.Model(inputs, outputs)

# %%
transformer = build_transfromer(head_size=128, num_heads=4, ff_dim=2, num_trans_blocks=4, mlp_units=[256], mlp_dropout=0.10, dropout=0.10, attention_axes=1)

# %%
transformer.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 5, 18)]              0         []
#
#  layer_normalization (Layer  (None, 5, 18)                36        ['input_1[0][0]']
#  Normalization)
#
#  multi_head_attention (Mult  (None, 5, 18)                38418     ['layer_normalization[0][0]',
#  iHeadAttention)                                                     'layer_normalization[0][0]']
#
#  dropout (Dropout)           (None, 5, 18)                0         ['multi_head_attention[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 5, 18)                0         ['dropout[0][0]',
#  Lambda)                                                             'input_1[0][0]']
#
#  layer_normalization_1 (Lay  (None, 5, 18)                36        ['tf.__operators__.add[0][0]']
#  erNormalization)
#
#  conv1d (Conv1D)             (None, 5, 2)                 38        ['layer_normalization_1[0][0]'
#                                                                     ]
#
#  dropout_1 (Dropout)         (None, 5, 2)                 0         ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 5, 18)                54        ['dropout_1[0][0]']
#
#  tf.__operators__.add_1 (TF  (None, 5, 18)                0         ['conv1d_1[0][0]',
#  OpLambda)                                                           'tf.__operators__.add[0][0]']
#
#  layer_normalization_2 (Lay  (None, 5, 18)                36        ['tf.__operators__.add_1[0][0]
#  erNormalization)                                                   ']
#
#  multi_head_attention_1 (Mu  (None, 5, 18)                38418     ['layer_normalization_2[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_2[0][0]
#                                                                     ']
#
#  dropout_2 (Dropout)         (None, 5, 18)                0         ['multi_head_attention_1[0][0]
#                                                                     ']
#
#  tf.__operators__.add_2 (TF  (None, 5, 18)                0         ['dropout_2[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  layer_normalization_3 (Lay  (None, 5, 18)                36        ['tf.__operators__.add_2[0][0]
#  erNormalization)                                                   ']
#
#  conv1d_2 (Conv1D)           (None, 5, 2)                 38        ['layer_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_3 (Dropout)         (None, 5, 2)                 0         ['conv1d_2[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 5, 18)                54        ['dropout_3[0][0]']
#
#  tf.__operators__.add_3 (TF  (None, 5, 18)                0         ['conv1d_3[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_2[0][0]
#                                                                     ']
#
#  layer_normalization_4 (Lay  (None, 5, 18)                36        ['tf.__operators__.add_3[0][0]
#  erNormalization)                                                   ']
#
#  multi_head_attention_2 (Mu  (None, 5, 18)                38418     ['layer_normalization_4[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_4[0][0]
#                                                                     ']
#
#  dropout_4 (Dropout)         (None, 5, 18)                0         ['multi_head_attention_2[0][0]
#                                                                     ']
#
#  tf.__operators__.add_4 (TF  (None, 5, 18)                0         ['dropout_4[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_3[0][0]
#                                                                     ']
#
#  layer_normalization_5 (Lay  (None, 5, 18)                36        ['tf.__operators__.add_4[0][0]
#  erNormalization)                                                   ']
#
#  conv1d_4 (Conv1D)           (None, 5, 2)                 38        ['layer_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_5 (Dropout)         (None, 5, 2)                 0         ['conv1d_4[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 5, 18)                54        ['dropout_5[0][0]']
#
#  tf.__operators__.add_5 (TF  (None, 5, 18)                0         ['conv1d_5[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_4[0][0]
#                                                                     ']
#
#  layer_normalization_6 (Lay  (None, 5, 18)                36        ['tf.__operators__.add_5[0][0]
#  erNormalization)                                                   ']
#
#  multi_head_attention_3 (Mu  (None, 5, 18)                38418     ['layer_normalization_6[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_6[0][0]
#                                                                     ']
#
#  dropout_6 (Dropout)         (None, 5, 18)                0         ['multi_head_attention_3[0][0]
#                                                                     ']
#
#  tf.__operators__.add_6 (TF  (None, 5, 18)                0         ['dropout_6[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  layer_normalization_7 (Lay  (None, 5, 18)                36        ['tf.__operators__.add_6[0][0]
#  erNormalization)                                                   ']
#
#  conv1d_6 (Conv1D)           (None, 5, 2)                 38        ['layer_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 5, 2)                 0         ['conv1d_6[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 5, 18)                54        ['dropout_7[0][0]']
#
#  tf.__operators__.add_7 (TF  (None, 5, 18)                0         ['conv1d_7[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_6[0][0]
#                                                                     ']
#
#  global_average_pooling1d (  (None, 5)                    0         ['tf.__operators__.add_7[0][0]
#  GlobalAveragePooling1D)                                            ']
#
#  dense (Dense)               (None, 256)                  1536      ['global_average_pooling1d[0][
#                                                                     0]']
#
#  dropout_8 (Dropout)         (None, 256)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    257       ['dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 156121 (609.85 KB)
# Trainable params: 156121 (609.85 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
def fit_transformer(transformer: tf.keras.Model):
    """
    Compiles and fits our transformer.
    """
    transformer.compile(
        loss="mse",
        optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=1e-3),
        metrics=["mae", 'mape'])

    callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-5)]
    start = time.time()
    hist = transformer.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=64, epochs=100, verbose=1, callbacks=callbacks).history
    print(time.time() - start)
    return hist

# %%
hist = fit_transformer(transformer)
# Out:
# Epoch 1/100
# 423/423 [==============================] - 10s 21ms/step - loss: 0.0146 - mae: 0.0777 - mape: 19.7233 - val_loss: 0.0188 - val_mae: 0.1273 - val_mape: 457.3661 - lr: 0.0010
# Epoch 2/100
# 423/423 [==============================] - 10s 23ms/step - loss: 0.0038 - mae: 0.0473 - mape: 13.5434 - val_loss: 0.0085 - val_mae: 0.0868 - val_mape: 270.8933 - lr: 0.0010
# Epoch 3/100
# 423/423 [==============================] - 10s 23ms/step - loss: 0.0029 - mae: 0.0411 - mape: 9.8718 - val_loss: 0.0053 - val_mae: 0.0651 - val_mape: 210.5728 - lr: 0.0010
# Epoch 4/100
# 423/423 [==============================] - 10s 24ms/step - loss: 0.0024 - mae: 0.0371 - mape: 9.0436 - val_loss: 0.0034 - val_mae: 0.0518 - val_mape: 185.9240 - lr: 0.0010
# Epoch 5/100
# 423/423 [==============================] - 10s 24ms/step - loss: 0.0022 - mae: 0.0349 - mape: 11.3180 - val_loss: 0.0030 - val_mae: 0.0499 - val_mape: 176.4426 - lr: 0.0010
# Epoch 6/100
# 423/423 [==============================] - 10s 23ms/step - loss: 0.0020 - mae: 0.0337 - mape: 12.8117 - val_loss: 0.0038 - val_mae: 0.0579 - val_mape: 198.5449 - lr: 0.0010
# Epoch 7/100
# 423/423 [==============================] - 10s 23ms/step - loss: 0.0020 - mae: 0.0333 - mape: 12.1829 - val_loss: 0.0012 - val_mae: 0.0306 - val_mape: 108.5869 - lr: 0.0010
# Epoch 8/100
# 423/423 [==============================] - 10s 23ms/step - loss: 0.0019 - mae: 0.0329 - mape: 11.2039 - val_loss: 0.0017 - val_mae: 0.0349 - val_mape: 130.4450 - lr: 0.0010
# Epoch 9/100
# 423/423 [==============================] - 10s 23ms/step - loss: 0.0019 - mae: 0.0323 - mape: 8.5225 - val_loss: 6.6344e-04 - val_mae: 0.0202 - val_mape: 75.0204 - lr: 0.0010
# Epoch 10/100
# 423/423 [==============================] - 9s 21ms/step - loss: 0.0018 - mae: 0.0316 - mape: 10.5470 - val_loss: 4.7619e-04 - val_mae: 0.0186 - val_mape: 47.6164 - lr: 0.0010
# Epoch 11/100
# 423/423 [==============================] - 9s 21ms/step - loss: 0.0018 - mae: 0.0315 - mape: 9.8151 - val_loss: 4.3420e-04 - val_mae: 0.0158 - val_mape: 45.0367 - lr: 0.0010
# Epoch 12/100
# 423/423 [==============================] - 9s 22ms/step - loss: 0.0018 - mae: 0.0314 - mape: 11.6417 - val_loss: 0.0013 - val_mae: 0.0326 - val_mape: 107.7096 - lr: 0.0010
# Epoch 13/100
# 423/423 [==============================] - 9s 22ms/step - loss: 0.0018 - mae: 0.0313 - mape: 9.3384 - val_loss: 4.6019e-04 - val_mae: 0.0185 - val_mape: 53.8043 - lr: 0.0010
# Epoch 14/100
# 423/423 [==============================] - 10s 23ms/step - loss: 0.0017 - mae: 0.0310 - mape: 9.4264 - val_loss: 3.0552e-04 - val_mae: 0.0137 - val_mape: 40.7908 - lr: 0.0010
# Epoch 15/100
# 423/423 [==============================] - 11s 26ms/step - loss: 0.0017 - mae: 0.0307 - mape: 9.0290 - val_loss: 3.5226e-04 - val_mae: 0.0144 - val_mape: 52.4577 - lr: 0.0010
# Epoch 16/100
# 423/423 [==============================] - 9s 21ms/step - loss: 0.0017 - mae: 0.0306 - mape: 11.6612 - val_loss: 2.6551e-04 - val_mae: 0.0125 - val_mape: 29.7042 - lr: 0.0010
# Epoch 17/100
# 423/423 [==============================] - 9s 21ms/step - loss: 0.0016 - mae: 0.0300 - mape: 7.1364 - val_loss: 2.4518e-04 - val_mae: 0.0122 - val_mape: 42.0508 - lr: 0.0010
# Epoch 18/100
# 423/423 [==============================] - 9s 21ms/step - loss: 0.0017 - mae: 0.0307 - mape: 7.1354 - val_loss: 3.2637e-04 - val_mae: 0.0143 - val_mape: 46.6337 - lr: 0.0010
# Epoch 19/100
# 423/423 [==============================] - 9s 21ms/step - loss: 0.0016 - mae: 0.0300 - mape: 6.9894 - val_loss: 3.3084e-04 - val_mae: 0.0141 - val_mape: 53.4805 - lr: 0.0010
# Epoch 20/100
# 423/423 [==============================] - 9s 21ms/step - loss: 0.0014 - mae: 0.0281 - mape: 8.2762 - val_loss: 3.9089e-04 - val_mae: 0.0161 - val_mape: 61.0504 - lr: 5.0000e-04
# Epoch 21/100
# 423/423 [==============================] - 9s 22ms/step - loss: 0.0014 - mae: 0.0281 - mape: 8.3420 - val_loss: 1.8024e-04 - val_mae: 0.0102 - val_mape: 28.3377 - lr: 5.0000e-04
# Epoch 22/100
# 423/423 [==============================] - 10s 23ms/step - loss: 0.0014 - mae: 0.0278 - mape: 6.3055 - val_loss: 1.9416e-04 - val_mae: 0.0104 - val_mape: 35.1272 - lr: 5.0000e-04
# Epoch 23/100
# 423/423 [==============================] - 10s 24ms/step - loss: 0.0014 - mae: 0.0281 - mape: 8.3724 - val_loss: 1.7443e-04 - val_mae: 0.0103 - val_mape: 22.2027 - lr: 5.0000e-04
# Epoch 24/100
# 423/423 [==============================] - 10s 25ms/step - loss: 0.0014 - mae: 0.0276 - mape: 7.0774 - val_loss: 1.1358e-04 - val_mae: 0.0074 - val_mape: 21.2763 - lr: 5.0000e-04
# Epoch 25/100
# 423/423 [==============================] - 11s 26ms/step - loss: 0.0014 - mae: 0.0279 - mape: 8.0886 - val_loss: 1.7569e-04 - val_mae: 0.0105 - val_mape: 30.1289 - lr: 5.0000e-04
# Epoch 26/100
# 423/423 [==============================] - 10s 23ms/step - loss: 0.0014 - mae: 0.0275 - mape: 8.0948 - val_loss: 1.2209e-04 - val_mae: 0.0081 - val_mape: 22.4320 - lr: 5.0000e-04
# Epoch 27/100
# 423/423 [==============================] - 10s 23ms/step - loss: 0.0013 - mae: 0.0267 - mape: 8.9915 - val_loss: 1.1244e-04 - val_mae: 0.0074 - val_mape: 20.1987 - lr: 2.5000e-04
# Epoch 28/100
# 423/423 [==============================] - 9s 21ms/step - loss: 0.0013 - mae: 0.0269 - mape: 7.8051 - val_loss: 1.6980e-04 - val_mae: 0.0099 - val_mape: 29.4899 - lr: 2.5000e-04
# Epoch 29/100
# 423/423 [==============================] - 9s 22ms/step - loss: 0.0013 - mae: 0.0267 - mape: 7.6705 - val_loss: 9.0032e-05 - val_mae: 0.0066 - val_mape: 21.6498 - lr: 2.5000e-04
# Epoch 30/100
# 423/423 [==============================] - 9s 21ms/step - loss: 0.0013 - mae: 0.0266 - mape: 7.9587 - val_loss: 1.0629e-04 - val_mae: 0.0075 - val_mape: 21.4872 - lr: 2.5000e-04
# Epoch 31/100
# 423/423 [==============================] - 9s 22ms/step - loss: 0.0013 - mae: 0.0266 - mape: 8.3530 - val_loss: 1.3380e-04 - val_mae: 0.0083 - val_mape: 25.1183 - lr: 2.5000e-04
# Epoch 32/100
# 423/423 [==============================] - 229s 542ms/step - loss: 0.0012 - mae: 0.0261 - mape: 8.0361 - val_loss: 1.1270e-04 - val_mae: 0.0081 - val_mape: 18.6663 - lr: 1.2500e-04
# Epoch 33/100
# 423/423 [==============================] - 9s 21ms/step - loss: 0.0012 - mae: 0.0261 - mape: 9.0811 - val_loss: 1.2507e-04 - val_mae: 0.0085 - val_mape: 27.0800 - lr: 1.2500e-04
# Epoch 34/100
# 423/423 [==============================] - 9s 20ms/step - loss: 0.0012 - mae: 0.0259 - mape: 7.0910 - val_loss: 8.9214e-05 - val_mae: 0.0065 - val_mape: 20.3479 - lr: 1.2500e-04
# Epoch 35/100
# 423/423 [==============================] - 9s 21ms/step - loss: 0.0013 - mae: 0.0262 - mape: 7.2123 - val_loss: 1.6088e-04 - val_mae: 0.0095 - val_mape: 29.1229 - lr: 1.2500e-04
# Epoch 36/100
# 423/423 [==============================] - 9s 21ms/step - loss: 0.0013 - mae: 0.0261 - mape: 7.2600 - val_loss: 8.6869e-05 - val_mae: 0.0065 - val_mape: 16.7567 - lr: 1.2500e-04
# Epoch 37/100
# 423/423 [==============================] - 9s 21ms/step - loss: 0.0012 - mae: 0.0258 - mape: 7.6238 - val_loss: 9.9723e-05 - val_mae: 0.0071 - val_mape: 22.4191 - lr: 6.2500e-05
# Epoch 38/100
# 423/423 [==============================] - 9s 21ms/step - loss: 0.0012 - mae: 0.0256 - mape: 7.1289 - val_loss: 8.5288e-05 - val_mae: 0.0066 - val_mape: 17.5934 - lr: 6.2500e-05
# Epoch 39/100
# 423/423 [==============================] - 9s 22ms/step - loss: 0.0012 - mae: 0.0257 - mape: 7.3104 - val_loss: 8.0660e-05 - val_mae: 0.0063 - val_mape: 16.9381 - lr: 6.2500e-05
# Epoch 40/100
# 423/423 [==============================] - 9s 22ms/step - loss: 0.0012 - mae: 0.0256 - mape: 7.1586 - val_loss: 8.7129e-05 - val_mae: 0.0064 - val_mape: 20.6598 - lr: 6.2500e-05
# Epoch 41/100
# 423/423 [==============================] - 9s 22ms/step - loss: 0.0012 - mae: 0.0254 - mape: 8.6556 - val_loss: 9.4399e-05 - val_mae: 0.0066 - val_mape: 21.7333 - lr: 6.2500e-05
# Epoch 42/100
# 423/423 [==============================] - 10s 23ms/step - loss: 0.0012 - mae: 0.0254 - mape: 7.7781 - val_loss: 9.0088e-05 - val_mae: 0.0068 - val_mape: 17.2365 - lr: 3.1250e-05
# Epoch 43/100
# 423/423 [==============================] - 10s 23ms/step - loss: 0.0012 - mae: 0.0256 - mape: 7.9142 - val_loss: 7.7888e-05 - val_mae: 0.0060 - val_mape: 16.9978 - lr: 3.1250e-05
# Epoch 44/100
# 423/423 [==============================] - 9s 22ms/step - loss: 0.0012 - mae: 0.0255 - mape: 7.6527 - val_loss: 7.7883e-05 - val_mae: 0.0060 - val_mape: 17.0973 - lr: 3.1250e-05
# Epoch 45/100
# 423/423 [==============================] - 9s 20ms/step - loss: 0.0012 - mae: 0.0255 - mape: 7.2317 - val_loss: 8.1184e-05 - val_mae: 0.0062 - val_mape: 17.3499 - lr: 3.1250e-05
# Epoch 46/100
# 423/423 [==============================] - 9s 20ms/step - loss: 0.0012 - mae: 0.0254 - mape: 7.6099 - val_loss: 8.0567e-05 - val_mae: 0.0062 - val_mape: 16.7073 - lr: 3.1250e-05
# Epoch 47/100
# 423/423 [==============================] - 9s 20ms/step - loss: 0.0012 - mae: 0.0255 - mape: 7.4052 - val_loss: 8.1014e-05 - val_mae: 0.0060 - val_mape: 19.3104 - lr: 3.1250e-05
# Epoch 48/100
# 423/423 [==============================] - 9s 20ms/step - loss: 0.0012 - mae: 0.0253 - mape: 7.8574 - val_loss: 7.6319e-05 - val_mae: 0.0057 - val_mape: 18.0653 - lr: 3.1250e-05
# Epoch 49/100
# 423/423 [==============================] - 9s 22ms/step - loss: 0.0012 - mae: 0.0252 - mape: 7.0024 - val_loss: 7.8990e-05 - val_mae: 0.0061 - val_mape: 17.4778 - lr: 1.5625e-05
# Epoch 50/100
# 423/423 [==============================] - 9s 21ms/step - loss: 0.0012 - mae: 0.0255 - mape: 7.2376 - val_loss: 7.6697e-05 - val_mae: 0.0058 - val_mape: 17.4779 - lr: 1.5625e-05
# Epoch 51/100
# 423/423 [==============================] - 9s 21ms/step - loss: 0.0012 - mae: 0.0251 - mape: 7.4065 - val_loss: 7.6458e-05 - val_mae: 0.0058 - val_mape: 17.4206 - lr: 1.5625e-05
# Epoch 52/100
# 423/423 [==============================] - 10s 23ms/step - loss: 0.0012 - mae: 0.0252 - mape: 6.6913 - val_loss: 7.3986e-05 - val_mae: 0.0057 - val_mape: 17.4158 - lr: 1.5625e-05
# Epoch 53/100
# 423/423 [==============================] - 10s 22ms/step - loss: 0.0012 - mae: 0.0253 - mape: 7.5759 - val_loss: 7.4405e-05 - val_mae: 0.0056 - val_mape: 17.7699 - lr: 1.5625e-05
# Epoch 54/100
# 423/423 [==============================] - 10s 24ms/step - loss: 0.0012 - mae: 0.0253 - mape: 7.2238 - val_loss: 7.0972e-05 - val_mae: 0.0054 - val_mape: 17.3596 - lr: 1.0000e-05
# Epoch 55/100
# 423/423 [==============================] - 11s 25ms/step - loss: 0.0012 - mae: 0.0251 - mape: 7.2935 - val_loss: 7.6100e-05 - val_mae: 0.0058 - val_mape: 17.2416 - lr: 1.0000e-05
# Epoch 56/100
# 423/423 [==============================] - 10s 24ms/step - loss: 0.0012 - mae: 0.0254 - mape: 7.5301 - val_loss: 7.5833e-05 - val_mae: 0.0057 - val_mape: 17.7766 - lr: 1.0000e-05
# Epoch 57/100
# 423/423 [==============================] - 11s 25ms/step - loss: 0.0012 - mae: 0.0253 - mape: 7.2095 - val_loss: 7.6421e-05 - val_mae: 0.0058 - val_mape: 16.9820 - lr: 1.0000e-05
# Epoch 58/100
# 423/423 [==============================] - 10s 24ms/step - loss: 0.0012 - mae: 0.0253 - mape: 6.3123 - val_loss: 7.5311e-05 - val_mae: 0.0057 - val_mape: 16.7673 - lr: 1.0000e-05
# Epoch 59/100
# 423/423 [==============================] - 11s 25ms/step - loss: 0.0012 - mae: 0.0254 - mape: 7.9550 - val_loss: 8.0916e-05 - val_mae: 0.0063 - val_mape: 16.7582 - lr: 1.0000e-05
# Epoch 60/100
# 423/423 [==============================] - 10s 23ms/step - loss: 0.0012 - mae: 0.0252 - mape: 6.9995 - val_loss: 7.7286e-05 - val_mae: 0.0060 - val_mape: 16.0928 - lr: 1.0000e-05
# Epoch 61/100
# 423/423 [==============================] - 707s 2s/step - loss: 0.0012 - mae: 0.0252 - mape: 7.2278 - val_loss: 8.0768e-05 - val_mae: 0.0061 - val_mape: 20.0596 - lr: 1.0000e-05
# Epoch 62/100
# 423/423 [==============================] - 9s 21ms/step - loss: 0.0012 - mae: 0.0250 - mape: 6.4097 - val_loss: 7.6225e-05 - val_mae: 0.0059 - val_mape: 17.8997 - lr: 1.0000e-05
# Epoch 63/100
# 423/423 [==============================] - 9s 21ms/step - loss: 0.0012 - mae: 0.0251 - mape: 7.3754 - val_loss: 7.6763e-05 - val_mae: 0.0059 - val_mape: 17.3324 - lr: 1.0000e-05
# Epoch 64/100
# 423/423 [==============================] - 9s 21ms/step - loss: 0.0012 - mae: 0.0251 - mape: 7.7033 - val_loss: 7.4559e-05 - val_mae: 0.0057 - val_mape: 16.6209 - lr: 1.0000e-05
# 1522.8484630584717

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

def evaluate(model, X_test, y_test):
    model.evaluate(X_test, y_test, verbose=1)
    y_pred = model.predict(X_test)

    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    mape = mean_absolute_percentage_error(y_test, y_pred)
    
    return mse, mae, mape
    
def plot_results(model, X_test, y_test):
    model.evaluate(X_test, y_test, verbose=1)
    y_pred = model.predict(X_test)
    # Plotting
    plt.figure(figsize=(15, 6))
    plt.plot(y_test, label='Actual Values')
    plt.plot(y_pred, label='Predicted Values')
    plt.title('Comparison of Actual and Predicted Values')
    plt.xlabel('Sample Index')
    plt.ylabel('Value')
    plt.legend()
    plt.show()

# %%
plot_results(transformer, X_train, y_train)
# Out:
# 846/846 [==============================] - 3s 3ms/step - loss: 1.7585e-04 - mae: 0.0081 - mape: 5.5591
# 846/846 [==============================] - 3s 3ms/step

# %%
plot_results(transformer, X_val, y_val)
# Out:
# 242/242 [==============================] - 1s 3ms/step - loss: 7.0972e-05 - mae: 0.0054 - mape: 17.3596
# 242/242 [==============================] - 1s 3ms/step

# %%
plot_results(transformer, X_test, y_test)
# Out:
# 121/121 [==============================] - 0s 3ms/step - loss: 1.8956e-04 - mae: 0.0092 - mape: 18.7608
# 121/121 [==============================] - 0s 3ms/step

# %%
# Extracting loss data from the history object
train_loss = hist['loss']
val_loss = hist['val_loss']

# Number of epochs actually completed (may be less than 50 due to early stopping)
epochs = range(len(train_loss))

# Plotting the loss per epoch
plt.figure(figsize=(15, 6))
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
summary = []

crypto = 'BTC'
transformer_model = 'Transformer'
mse, mae, mape = evaluate(transformer, X_test, y_test)

summary.append({
    'Data': crypto,
    'Model': transformer_model,
    'MSE': mse,
    'MAE': mae,
    'MAPE': mape
})

# Convert list to DataFrame
tr_df = pd.DataFrame(summary)
tr_df
# Out:
# 121/121 [==============================] - 0s 3ms/step - loss: 1.8956e-04 - mae: 0.0092 - mape: 18.7608
# 121/121 [==============================] - 0s 3ms/step
#   Data        Model      MSE       MAE      MAPE
# 0  BTC  Transformer  0.00019  0.009211  0.187608
